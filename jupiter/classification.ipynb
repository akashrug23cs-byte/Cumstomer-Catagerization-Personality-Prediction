# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (2.3.0)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv(r"./Data/clustered_data.csv")

# %%
df
# Out:
#       Education  Marital Status   Income  Recency  Wines  Fruits  Meat   Fish  \
# 0             2               0  58138.0       58    635      81   546  120.5
# 1             2               0  46344.0       38     11       1     6    2.0
# 2             2               1  71613.0       26    426      49   127  111.0
# 3             2               1  26646.0       26     11       4    20   10.0
# 4             4               1  58293.0       94    173      43   118   46.0
# ...         ...             ...      ...      ...    ...     ...   ...    ...
# 2235          2               1  61223.0       46    709      43   182   42.0
# 2236          4               1  64014.0       56    406       0    30    0.0
# 2237          2               0  56981.0       91    908      48   217   32.0
# 2238          3               1  69245.0        8    428      30   214   80.0
# 2239          4               1  52869.0       40     84       3    61    2.0
#
#       Sweets   Gold  ...  Catalog  Store  NumWebVisitsMonth  Age  Children  \
# 0         81   88.0  ...       10      4                  7   68         0
# 1          1    6.0  ...        1      2                  5   71         2
# 2         21   42.0  ...        2     10                  4   60         0
# 3          3    5.0  ...        0      4                  6   41         1
# 4         27   15.0  ...        3      6                  5   44         1
# ...      ...    ...  ...      ...    ...                ...  ...       ...
# 2235      81  126.5  ...        3      4                  5   58         1
# 2236       0    8.0  ...        2      5                  7   79         3
# 2237      12   24.0  ...        3     13                  6   44         0
# 2238      30   61.0  ...        5     10                  3   69         1
# 2239       1   21.0  ...        1      4                  7   71         2
#
#       total_spend  total_promo  Parental_status  Days_as_Customer  cluster
# 0          1617.0            0                0            4684.0        0
# 1            27.0            0                1            4134.0        1
# 2           776.0            0                0            4333.0        0
# 3            53.0            0                1            4160.0        1
# 4           422.0            0                1            4182.0        2
# ...           ...          ...              ...               ...      ...
# 2235       1341.0            0                1            4402.0        2
# 2236        444.0            1                1            4040.0        2
# 2237       1241.0            1                0            4176.0        0
# 2238        843.0            0                1            4177.0        0
# 2239        172.0            0                1            4643.0        1
#
# [2240 rows x 22 columns]

# %%
df['cluster'].unique()
# Out:
# array([0, 1, 2])

# %%
print(df.shape)
# Out:
# (2240, 22)

# %%
#now classify the df into x(independent variable) and y(dependent variable)
x=df.drop("cluster",axis=1)
y=df['cluster']

# %%
x.head()
# Out:
#    Education  Marital Status   Income  Recency  Wines  Fruits  Meat   Fish  \
# 0          2               0  58138.0       58    635      81   546  120.5
# 1          2               0  46344.0       38     11       1     6    2.0
# 2          2               1  71613.0       26    426      49   127  111.0
# 3          2               1  26646.0       26     11       4    20   10.0
# 4          4               1  58293.0       94    173      43   118   46.0
#
#    Sweets  Gold  ...  Web  Catalog  Store  NumWebVisitsMonth  Age  Children  \
# 0      81  88.0  ...    8       10      4                  7   68         0
# 1       1   6.0  ...    1        1      2                  5   71         2
# 2      21  42.0  ...    8        2     10                  4   60         0
# 3       3   5.0  ...    2        0      4                  6   41         1
# 4      27  15.0  ...    5        3      6                  5   44         1
#
#    total_spend  total_promo  Parental_status  Days_as_Customer
# 0       1617.0            0                0            4684.0
# 1         27.0            0                1            4134.0
# 2        776.0            0                0            4333.0
# 3         53.0            0                1            4160.0
# 4        422.0            0                1            4182.0
#
# [5 rows x 21 columns]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2240 entries, 0 to 2239
# Series name: cluster
# Non-Null Count  Dtype
# --------------  -----
# 2240 non-null   int64
# dtypes: int64(1)
# memory usage: 17.6 KB

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from scikit-learn) (1.16.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#train test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.shape
# Out:
# (1792, 21)

# %%
x_test.shape
# Out:
# (448, 21)

# %%
# !pip install xgboost
# !pip install catboost
# Out:
# Collecting xgboost
#   Using cached xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from xgboost) (2.3.1)
# Requirement already satisfied: scipy in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from xgboost) (1.16.0)
# Using cached xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.2
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: catboost in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (3.10.3)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (2.3.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (2.3.0)
# Requirement already satisfied: scipy in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: plotly in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (6.2.0)
# Requirement already satisfied: six in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ritesh\desktop\customercategorizer\myenv\lib\site-packages (from plotly->catboost) (1.45.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#grid search cv for selectin best model form the multiple model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn import metrics

# %%
#creating a dictionary of all the object of the algorithm above
models={
    "logictic":LogisticRegression(),
    "randomforest":RandomForestClassifier(),
    "adaboost":AdaBoostClassifier(),
    "gradient":GradientBoostingClassifier(),
    "kneighbour":KNeighborsClassifier(),
    "decisiontree":DecisionTreeClassifier(),
    "svc":SVC(),
    "xgboost":XGBClassifier(),
    "catboost":CatBoostClassifier(verbose=False)
}

# %%
models
# Out:
# {'logictic': LogisticRegression(),
#  'randomforest': RandomForestClassifier(),
#  'adaboost': AdaBoostClassifier(),
#  'gradient': GradientBoostingClassifier(),
#  'kneighbour': KNeighborsClassifier(),
#  'decisiontree': DecisionTreeClassifier(),
#  'svc': SVC(),
#  'xgboost': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric=None, feature_types=None,
#                feature_weights=None, gamma=None, grow_policy=None,
#                importance_type=None, interaction_constraints=None,
#                learning_rate=None, max_bin=None, max_cat_threshold=None,
#                max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#                max_leaves=None, min_child_weight=None, missing=nan,
#                monotone_constraints=None, multi_strategy=None, n_estimators=None,
#                n_jobs=None, num_parallel_tree=None, ...),
#  'catboost': <catboost.core.CatBoostClassifier at 0x1445c04b230>}

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
#fuction which evaluates the model for selecting the best model form them
def evaluate(models,x_train,y_train,x_test,y_test):

    model_name=[]
    pred_score=[]

    for i in range (len(list(models))):
        model=list(models.values())[i]
        #traing the model
        model.fit(x_train,y_train)

        #predicting the model
        y_pred=model.predict(x_test)
        score=accuracy_score(y_test,y_pred)
        name=list(models.keys())[i]
        print("the accuracy score for the model "f'{name} is {score}')
        model_name.append(name)
        pred_score.append(score)

    print()
    data=pd.DataFrame()
    data['Name']=model_name
    data['Score']=pred_score
    return data

# %%
data=evaluate(models,x_train,y_train,x_test,y_test)
# Out:
# the accuracy score for the model logictic is 0.875
# the accuracy score for the model randomforest is 0.9620535714285714
# the accuracy score for the model adaboost is 0.9441964285714286
# the accuracy score for the model gradient is 0.9642857142857143
# the accuracy score for the model kneighbour is 0.8303571428571429
# the accuracy score for the model decisiontree is 0.9330357142857143
# the accuracy score for the model svc is 0.765625
# the accuracy score for the model xgboost is 0.9620535714285714
# the accuracy score for the model catboost is 0.9665178571428571

# %%
data.sort_values('Score')
# Out:
#            Name     Score
# 6           svc  0.765625
# 4    kneighbour  0.830357
# 0      logictic  0.875000
# 5  decisiontree  0.933036
# 2      adaboost  0.944196
# 1  randomforest  0.962054
# 7       xgboost  0.962054
# 3      gradient  0.964286
# 8      catboost  0.966518

# %%
#so catboost is giving the highest accuracy so we use catbooost
from catboost import CatBoostClassifier

model=CatBoostClassifier(verbose=False)

# %%
#applying the grid searcah cv 
from sklearn.model_selection import RandomizedSearchCV
params= {
    'depth': [4, 6, 8],
    'learning_rate': [0.05, 0.1],
    'iterations': [200, 500],
    'l2_leaf_reg': [1, 3],
}

grid = RandomizedSearchCV(estimator=model,
                    param_distributions=params,
                    n_iter=25,
                    scoring='accuracy',
                    cv=5,  # all CPU cores
                    verbose=1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# RandomizedSearchCV(cv=5,
#                    estimator=<catboost.core.CatBoostClassifier object at 0x000001445C299D10>,
#                    n_iter=25,
#                    param_distributions={'depth': [4, 6, 8],
#                                         'iterations': [200, 500],
#                                         'l2_leaf_reg': [1, 3],
#                                         'learning_rate': [0.05, 0.1]},
#                    scoring='accuracy', verbose=1)

# %%
print(grid.best_score_)
# Out:
# 0.9787958481816343

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'l2_leaf_reg': 1, 'iterations': 500, 'depth': 4}

# %%
y_pred=grid.best_estimator_.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.
# 55:	learn: 0.0705033	total: 232ms	remaining: 183ms
# 56:	learn: 0.0688358	total: 238ms	remaining: 180ms
# 57:	learn: 0.0670393	total: 242ms	remaining: 175ms
# 58:	learn: 0.0653870	total: 247ms	remaining: 172ms
# 59:	learn: 0.0638389	total: 252ms	remaining: 168ms
# 60:	learn: 0.0631473	total: 256ms	remaining: 164ms
# 61:	learn: 0.0620103	total: 261ms	remaining: 160ms
# 62:	learn: 0.0609925	total: 266ms	remaining: 156ms
# 63:	learn: 0.0600925	total: 271ms	remaining: 153ms
# 64:	learn: 0.0592738	total: 273ms	remaining: 147ms
# 65:	learn: 0.0583241	total: 278ms	remaining: 143ms
# 66:	learn: 0.0569433	total: 281ms	remaining: 139ms
# 67:	learn: 0.0559453	total: 286ms	remaining: 134ms
# 68:	learn: 0.0548165	total: 290ms	remaining: 130ms
# 69:	learn: 0.0539204	total: 294ms	remaining: 126ms
# 70:	learn: 0.0533838	total: 298ms	remaining: 122ms
# 71:	learn: 0.0525448	total: 302ms	remaining: 117ms
# 72:	learn: 0.0516084	total: 306ms	remaining: 113ms
# 73:	learn: 0.0507283	total: 310ms	remaining: 109ms
# 74:	learn: 0.0497962	total: 313ms	remaining: 104ms
# 75:	learn: 0.0488738	total: 318ms	remaining: 100ms
# 76:	learn: 0.0480142	total: 322ms	remaining: 96.2ms
# 77:	learn: 0.0475744	total: 326ms	remaining: 91.9ms
# 78:	learn: 0.0467834	total: 331ms	remaining: 88ms
# 79:	learn: 0.0459878	total: 335ms	remaining: 83.7ms
# 80:	learn: 0.0450426	total: 339ms	remaining: 79.6ms
# 81:	learn: 0.0443360	total: 343ms	remaining: 75.4ms
# 82:	learn: 0.0434907	total: 348ms	remaining: 71.3ms
# 83:	learn: 0.0426198	total: 352ms	remaining: 67ms
# 84:	learn: 0.0418969	total: 354ms	remaining: 62.4ms
# 85:	learn: 0.0410565	total: 358ms	remaining: 58.2ms
# 86:	learn: 0.0406570	total: 362ms	remaining: 54.1ms
# 87:	learn: 0.0399542	total: 365ms	remaining: 49.8ms
# 88:	learn: 0.0390861	total: 369ms	remaining: 45.7ms
# 89:	learn: 0.0382789	total: 373ms	remaining: 41.5ms
# 90:	learn: 0.0377437	total: 377ms	remaining: 37.3ms
# 91:	learn: 0.0369789	total: 381ms	remaining: 33.2ms
# 92:	learn: 0.0362876	total: 385ms	remaining: 29ms
# 93:	learn: 0.0354585	total: 389ms	remaining: 24.8ms
# 94:	learn: 0.0347582	total: 394ms	remaining: 20.7ms
# 95:	learn: 0.0340011	total: 397ms	remaining: 16.5ms
# 96:	learn: 0.0335311	total: 401ms	remaining: 12.4ms
# 97:	learn: 0.0327577	total: 405ms	remaining: 8.27ms
# 98:	learn: 0.0321278	total: 410ms	remaining: 4.14ms
# 99:	learn: 0.0314346	total: 413ms	remaining: 0us

# %%
y_pred=model.predict(x_test)
print("The accuracy of the model is :" ,accuracy_score(y_test,y_pred))
# Out:
# The accuracy of the model is : 0.9665178571428571

# %%
#confusion matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[111,   1,   6],
#        [  0, 192,   1],
#        [  4,   3, 130]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95       118
#            1       0.98      0.99      0.99       193
#            2       0.95      0.95      0.95       137
#
#     accuracy                           0.97       448
#    macro avg       0.96      0.96      0.96       448
# weighted avg       0.97      0.97      0.97       448

# %%
#display the confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_estimator(model, x_test, y_test)

# %%
import pickle
import os

# Save the trained model inside 'Data' folder
with open("Data/model.pkl", "wb") as f:
    pickle.dump(model, f)
